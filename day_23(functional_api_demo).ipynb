# %% [markdown]
# <a href="https://colab.research.google.com/github/yogesh-bhattarai/100_days_of_deeplearning/blob/main/day_23(functional_api_demo).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Model

# %%
model=Model(inputs=x,outputs=[output1,output2])

# %%
from keras.layers import *

# %%
x=Input(shape=(3,))

# %%
hidden1=Dense(128,activation='relu')(x)
hidden2=Dense(64,activation='relu')(hidden1)


output1=Dense(1,activation='sigmoid')(hidden1)
output2=Dense(1,activation='sigmoid')(hidden2)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 3)]                  0         []
#
#  dense (Dense)               (None, 128)                  512       ['input_1[0][0]']
#
#  dense_1 (Dense)             (None, 64)                   8256      ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    129       ['dense[0][0]']
#
#  dense_3 (Dense)             (None, 1)                    65        ['dense_1[0][0]']
#
# ...
# Total params: 8962 (35.01 KB)
# Trainable params: 8962 (35.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model,show_shapes=True)
